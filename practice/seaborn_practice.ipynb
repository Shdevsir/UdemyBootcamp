# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(tips['total_bill'], kde=True)

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.residplot(x='total_bill', y='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species')

# %%
sns.countplot(x='day', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.barplot(x='day', y='tip', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
tip2 = tips.corr()

# %%
sns.heatmap(tip2, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='smoker', data=tips)
sns.set_style('darkgrid')

# %%
df1 = sns.load_dataset('tips')
df2 = pd.read_csv('204.ece.csv')
df2
# Out:
#       Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03         NaN         NaN      C  Dollars
# 1           ECTA.S19A1  2002.03         NaN         NaN      C  Dollars
# 2           ECTA.S19A1  2003.03         NaN         NaN      C  Dollars
# 3           ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
# ...                ...      ...         ...         ...    ...      ...
# 16025       ECTQ.S4AXP  2018.03        47.2         NaN      F  Percent
# 16026       ECTQ.S4AXP  2018.06        48.6         NaN      F  Percent
# 16027       ECTQ.S4AXP  2018.09        48.2         NaN      F  Percent
# 16028       ECTQ.S4AXP  2018.12        46.6         NaN      F  Percent
# 16029       ECTQ.S4AXP  2019.03        45.8         NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
x1 = np.random.rand(100, 5)
x2 = np.random.rand(10, 5)

# %%
df3 = pd.DataFrame(x1, columns=['a', 'b', 'c', 'd', 'e'])

# %%
df3
# Out:
#            a         b         c         d         e
# 0   0.455218  0.891709  0.231652  0.328662  0.255600
# 1   0.670210  0.260321  0.899502  0.646009  0.942977
# 2   0.924639  0.987492  0.108566  0.647711  0.061177
# 3   0.566449  0.553335  0.082084  0.591317  0.747235
# 4   0.330074  0.764619  0.183380  0.235440  0.305383
# ..       ...       ...       ...       ...       ...
# 95  0.110610  0.537853  0.437154  0.866683  0.238586
# 96  0.196649  0.755587  0.725333  0.844422  0.904900
# 97  0.143532  0.876032  0.864205  0.973209  0.859445
# 98  0.802391  0.698072  0.457700  0.170582  0.689558
# 99  0.244763  0.321142  0.676168  0.570145  0.609464
#
# [100 rows x 5 columns]

# %%
df4 = pd.DataFrame(x2, columns=['a', 'b', 'c', 'd', 'e'])

# %%
df4.plot.scatter(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df3.plot.line()
# Out:
# <AxesSubplot:>

# %%
df3['c'].plot.line()
# Out:
# <AxesSubplot:>

# %%
df4.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df4.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df4.plot.area()
# Out:
# <AxesSubplot:>

# %%
import cufflinks as cf
import plotly as pl
import plotly.offline as po

# %%
po.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df11 = pd.DataFrame(np.random.rand(100, 5), columns=['a', 'b', 'c', 'd', 'e'])

# %%
df22 = pd.DataFrame({'x':['a','b','c','d','e'], 'y':[1,2,3,4,5],'z':[6,7,8,4,3]})

# %%
df11.iplot(kind='scatter')
# Out:
# <div>                            <div id="0efb04a3-105b-4b07-829b-a95957bde266" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df11.iplot(kind='surface')
# Out:
# <div>                            <div id="1347827f-7c6c-40da-a94f-9c1be7a73fe0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df11.iplot(kind='bubble', x='a', y='b', size='c')
# Out:
# <div>                            <div id="55fe591f-631c-44be-b2c3-ffec4188162d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
